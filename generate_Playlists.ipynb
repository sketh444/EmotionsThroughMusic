# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import json
import numpy as np
import pandas as pd
import random

# %%
cid ='a29b7bc0f80d4d10a19e6fdc3c401c13'
secret ='4f6c9e3111574485b3f94cdc3e26e089'

scope = 'user-library-read playlist-modify-public'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
##########################combo dataset###############################################################

# %%
happy_songs = pd.read_csv('Downloads/outputted_happy_songs.csv')
sad_songs = pd.read_csv('Downloads/outputted_sad_songs.csv')

# %%
#add 'spotify:track:' to spotify ids in df 

for index, row in happy_songs.iterrows():
    songId = str(happy_songs['track_id'][index])
    happy_songs['track_id'][index] = 'spotify:track:' + songId

happy_songs
# Out:
# <ipython-input-52-3d8cf4388899>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   happy_songs['track_id'][index] = 'spotify:track:' + songId
#       Unnamed: 0  Unnamed: 0.1  acousticness  \
# 0              0       11879.0       0.00522
# 1              1         739.0       0.09290
# 2              2       18110.0       0.32600
# 3              3       13456.0       0.02450
# 4              4         998.0       0.64300
# ...          ...           ...           ...
# 1606        1606        4376.0           NaN
# 1607        1607        4533.0           NaN
# 1608        1608        1343.0           NaN
# 1609        1609         754.0           NaN
# 1610        1610         701.0           NaN
#
#                                              album        artist  \
# ...

# %%
uris = []

for index, row in happy_songs.iterrows():
    uris.append(happy_songs['track_id'][index])

print(uris[:100])
# Out:
# ['spotify:track:524wRHQekJJvQWtAIy115v', 'spotify:track:0eXU92qkEfIWu4SQOILFU3', 'spotify:track:7rf5YnDlD0K2TZnv81dOBq', 'spotify:track:5RcuACCOhgoc4ZH57AVCLA', 'spotify:track:0iHO8dmXhSYCgfow7ckt9W', 'spotify:track:11dxtPJKR4E0wlSr0A0t47', 'spotify:track:6ijuIOZJcPMGgEMcv3pPGS', 'spotify:track:1CSk9lJFJt4OdcvOH5iK61', 'spotify:track:2gOYY2glUc6XMTnzBG59I4', 'spotify:track:2NVt7fxr5GsqTkGwYXcNTE', 'spotify:track:33CRyVka4ZEHeJ02w7nT2L', 'spotify:track:1euQrkGwRPQod7kcddoeJ5', 'spotify:track:2Vx8E3K5icPZR7OCklWBXX', 'spotify:track:3m2Bsp7otjIddiGoTaiSKO', 'spotify:track:2Hmxhwfyh0AzIGBjM7cynK', 'spotify:track:6uSa5iCMwPr10Ftpz8w09b', 'spotify:track:68PDydciw4W2e16wCbr9tv', 'spotify:track:2GHNZvjA57wLRl4FVk0MhS', 'spotify:track:6U2vGiMNVhJiJqxrlu18uV', 'spotify:track:7zye9v6B785eFWEFYs13C2', 'spotify:track:2RISD4aJrioDB54exm5WWM', 'spotify:track:69X5gWMpn3GpmfAg9hpQXJ', 'spotify:track:0Czg21zFuXypqp9S76d4TC', 'spotify:track:07CyrZF9eVd02zzIse7tZA', 'spotify:track:2ZUpK7zEZHyewSn6b57AHW
# ...

# %%
# happy playlist id ----- spotify:playlist:2BoKXDL7L1i8yYtk38iYVP

#sp.playlist_add_items('2BoKXDL7L1i8yYtk38iYVP', '7rf5YnDlD0K2TZnv81dOBq')

uris = []

for index, row in happy_songs.iterrows():
    uris.append(happy_songs['track_id'][index])
    
uris_100 = uris[:100]



endpoint_url = f"https://api.spotify.com/v1/playlists/2BoKXDL7L1i8yYtk38iYVP/tracks"

request_body = json.dumps({
          "uris" : uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQB9xUF_i49q8SECSs9vCeIZ8NBmsEFtoi_8yX27E7GyuKJYSSiY_RPwEx_pJc0mot4Ilrlg0uuE3F4nmJ7xCN5oE8R9KRIpLUAtfNLB5QE0N-Eurne8C--BCU0VaZFMLvTWPEwf854lyELwEIBE_cR-ynfPJ8K7V4KdANMf1Q2ugSJDoAOX9b87U7zpLZHtbA"})

print(response.status_code)
# Out:
# 201

# %%
#add 'spotify:track:' to spotify ids in df 

for index, row in sad_songs.iterrows():
    songId = str(sad_songs['track_id'][index])
    sad_songs['track_id'][index] = 'spotify:track:' + songId

sad_songs
# Out:
# <ipython-input-68-8f954c996362>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sad_songs['track_id'][index] = 'spotify:track:' + songId
#       Unnamed: 0  Unnamed: 0.1  acousticness  \
# 0              0       17061.0        0.0914
# 1              1       17162.0        0.0252
# 2              2        9231.0        0.0948
# 3              3       12820.0        0.1230
# 4              4         623.0        0.0275
# ...          ...           ...           ...
# 2761        2761        4786.0           NaN
# 2762        2762        4975.0           NaN
# 2763        2763        2869.0           NaN
# 2764        2764         121.0           NaN
# 2765        2765        3641.0           NaN
#
#                                  album                            artist  \
# ...

# %%
#sad playlist id ----- spotify:playlist:2VCj4LT5SOcsa5WdHBfA70

uris = []

for index, row in sad_songs.iterrows():
    uris.append(sad_songs['track_id'][index])
    
#uris_100 = uris[:100]
uris_100 = random.sample(uris, 100)


endpoint_url = f"https://api.spotify.com/v1/playlists/2VCj4LT5SOcsa5WdHBfA70/tracks"

request_body = json.dumps({
          "uris" : uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQA24GtAL0pxoz_sYbKYQODZgG9E7rzuKG338FsTFL_4mikNO9k4c9qFp7dyXVGXcNxbsJJgressXcHDZvbXCCZUjwfOK6XueWUBW5uIsR09vgZwdIAFo9Wdz3fkCawDEEWyQLJVY5-v-34WjIaPHWAQVQxJHOpN7y-WvSR0k2idujDqHZzwMC9i56AE3e_U9Oqt_8Dfmfgn_hMMXd4r1RPjFOUEW6I"})

print(response.status_code)
# Out:
# 201

# %%
#########################################labeled songs##########################################

# %%
labeled_songs = pd.read_csv('Downloads/labled_songs_predictions.csv')

# %%
#add 'spotify:track:' to spotify ids in df 

for index, row in labeled_songs.iterrows():
    songId = str(labeled_songs['track_id'][index])
    labeled_songs['track_id'][index] = 'spotify:track:' + songId

labeled_songs
# Out:
# <ipython-input-76-b33f8c1e2389>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_songs['track_id'][index] = 'spotify:track:' + songId
#       Unnamed: 0  Unnamed: 0.1                              track_id  \
# 0              0          4422  spotify:track:1VFObW6RUUrKjWY0SahdMa
# 1              1          1591  spotify:track:0q9YVW7oLuDqxfjGTxb7Lx
# 2              2         13399  spotify:track:5QIKZWOHDPbGh5EpSqCXMG
# 3              3          4722  spotify:track:1zK7i2QyuCmpYE209BMcPZ
# 4              4         17104  spotify:track:7CMAwm7mEkZkkaBl82DicE
# ...          ...           ...                                   ...
# 6995        6995          9570  spotify:track:43jJTO4MBgmaRybAaIHVA3
# 6996        6996           295  spotify:track:088eGKZm5dgDxFauCEwOqp
# ...

# %%
happy_uris = []
sad_uris = []

for index, row in labeled_songs.iterrows():
    if labeled_songs['isHappy_pred'][index] == 1:
        happy_uris.append(str(labeled_songs['track_id'][index]))
    if labeled_songs['isSad_pred'][index] == 1:
        sad_uris.append(str(labeled_songs['track_id'][index]))
        
happy_uris_100 = random.sample(happy_uris, 100)
sad_uris_100 = random.sample(sad_uris, 100)

# %%
#happy playlist id (labled) ----- spotify:playlist:4a59BYLVwShht3AQGfy5XA

endpoint_url = f"https://api.spotify.com/v1/playlists/4a59BYLVwShht3AQGfy5XA/tracks"

request_body = json.dumps({
          "uris" : happy_uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQAZjXAcPIH2qi1SZlkMabCe_EDoX7a_7kTyO6o48rS3LjKVbaxUxRY6zXNG2eNtfGwR4wRPfpgkYaVy4a3kgmqJncrTZUW5ndMTxmReGhwzOD5yPExyrDauvVcgBGEBS2lSVeqLEUMRUTpVsmxAv3tu0mk4V_Sga_duAVR8acGxdd4QHsMFa1sumMG-9-7hSuYQzpvH9Uhq-LIVKQpa9y-Gj9lKLR8"})

print(response.status_code)
# Out:
# 201

# %%
#sad playlist id (labled) ----- spotify:playlist:5PacWMqLKeYAcv1s4Q4WCT

endpoint_url = f"https://api.spotify.com/v1/playlists/5PacWMqLKeYAcv1s4Q4WCT/tracks"

request_body = json.dumps({
          "uris" : sad_uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQAwJPMMDqiRV8L3vMxrKeaTxv6qZUduZ6E9DJ4jHC_oAqxuMaF1pi72O01x-aHJ7pv-ZhF-CojPgPeu5npfBauF56Gu3Pfss4_R7Muu3iiowdZeqR0ecL37zdi4HsPj_5q0jpQwclE1wfFqiyimxDer-faLm4rH3-YxHiSIXvkwhn7xiFReqy3KEK1hOSunAahGWf_xtb4sSa1hm5wU921RFq6aq2Q"})

print(response.status_code)
# Out:
# 201

# %%
#########################################spotify songs##########################################

# %%
spotify_songs = pd.read_csv('Downloads/spotify_songs_predictions.csv')

# %%
#add 'spotify:track:' to spotify ids in df 

for index, row in spotify_songs.iterrows():
    songId = str(spotify_songs['track_id'][index])
    spotify_songs['track_id'][index] = 'spotify:track:' + songId

spotify_songs
# Out:
# <ipython-input-10-5ec4719c32bf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spotify_songs['track_id'][index] = 'spotify:track:' + songId
#       Unnamed: 0  Unnamed: 0.1                              track_id  \
# 0              0          8772  spotify:track:3rLZh34oJ1KzLkYwPVYUgP
# 1              1          8821  spotify:track:3ScJy88F8KqGDfWu8XJhHx
# 2              2          1730  spotify:track:0RZXNlGPvfMo54fd6uCvAT
# 3              3          7881  spotify:track:3fCqWsYPCPdLteUpeIOeyQ
# 4              4          7142  spotify:track:31QRCKy7JIwPBaQl9ArGBz
# ...          ...           ...                                   ...
# 5995        5995           144  spotify:track:04g1aQFzaegB7ovWaMMIzz
# 5996        5996          5971  spotify:track:2LBqCSwhJGcFQeTHMVGwy3
# ...

# %%
happy_spot_uris = []
sad_spot_uris = []

for index, row in spotify_songs.iterrows():
    if spotify_songs['isHappy_pred'][index] == 1:
        happy_spot_uris.append(str(spotify_songs['track_id'][index]))
    if spotify_songs['isSad_pred'][index] == 1:
        sad_spot_uris.append(str(spotify_songs['track_id'][index]))
        
happy_spot_uris_100 = random.sample(happy_spot_uris, 100)
sad_spot_uris_100 = random.sample(sad_spot_uris, 100)

# %%
#happy playlist id (labled) ----- spotify:playlist:13WYgcPLIC7EKGVFareF6z

endpoint_url = f"https://api.spotify.com/v1/playlists/13WYgcPLIC7EKGVFareF6z/tracks"

request_body = json.dumps({
          "uris" : happy_spot_uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQDMr6mnoP7FWMITjZeQhB-h9nIu8N-BkcVrIeCWgndQXpjG5kw8e5bAk-Jg7nAuvcXXnr-JKEhU-Kt8e1-Uvl6XFg9uDawN7qLILAK1bPf4-mesR6r9hvR_WrL6kBwnoX9N7lTfBia4JwQyqsdK6ar5jRCVntJwYYHh0mvbEE67VqvgsavcRLkNU_0dvtHiZvyz08Jnj8szshyeG2Q73T84bopWF28"})

print(response.status_code)
# Out:
# 201

# %%
#sad playlist id (labled) ----- spotify:playlist:7Efih4u6rw2qdjgWIuG7NZ

endpoint_url = f"https://api.spotify.com/v1/playlists/7Efih4u6rw2qdjgWIuG7NZ/tracks"

request_body = json.dumps({
          "uris" : sad_spot_uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQBH_OfNYHkt0-3WkHCJKWT4zT7XxqEu-7VA91h27U7L9k4KCJYEl3gn8y6JU9aYcfGzJ4TUaf1cga7EUlpjZwz3IUIC1YiJZN4f2yZbvp-YUUBKRNxpYfoEx4_GJvsa-CCaz10aQCRl1ZV2o0fu72b5R-MJeQnqh1DccjLRouNZpG37KE5Ceg3G-NzBmwGsu4r8NJdYkeC_ZGFwY0t_hljfrKPgFrs"})

print(response.status_code)
# Out:
# 201

# %%
############################audio features#############################################

# %%
audio_songs = pd.read_csv('Downloads/audio_features_predictions.csv')

# %%
#add 'spotify:track:' to spotify ids in df 

for index, row in audio_songs.iterrows():
    songId = str(audio_songs['track_id'][index])
    audio_songs['track_id'][index] = 'spotify:track:' + songId

audio_songs
# Out:
# <ipython-input-3-5fcfcc820274>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   audio_songs['track_id'][index] = 'spotify:track:' + songId
#       Unnamed: 0  Unnamed: 0.1                              track_id  \
# 0              0          8772  spotify:track:3rLZh34oJ1KzLkYwPVYUgP
# 1              1          8821  spotify:track:3ScJy88F8KqGDfWu8XJhHx
# 2              2          1730  spotify:track:0RZXNlGPvfMo54fd6uCvAT
# 3              3          7881  spotify:track:3fCqWsYPCPdLteUpeIOeyQ
# 4              4          7142  spotify:track:31QRCKy7JIwPBaQl9ArGBz
# ...          ...           ...                                   ...
# 5995        5995           144  spotify:track:04g1aQFzaegB7ovWaMMIzz
# 5996        5996          5971  spotify:track:2LBqCSwhJGcFQeTHMVGwy3
# ...

# %%
happy_audio_uris = []
sad_audio_uris = []

for index, row in audio_songs.iterrows():
    if audio_songs['audio_features_preds'][index] == 1:
        happy_audio_uris.append(str(audio_songs['track_id'][index]))
    if audio_songs['audio_features_preds'][index] == 0:
        sad_audio_uris.append(str(audio_songs['track_id'][index]))
        
happy_audio_uris_100 = random.sample(happy_audio_uris, 100)
sad_audio_uris_100 = random.sample(sad_audio_uris, 100)

# %%
#sad playlist id (audio) ----- spotify:playlist:2A03qMx2HtO6TGxZJQcf2N

endpoint_url = f"https://api.spotify.com/v1/playlists/2A03qMx2HtO6TGxZJQcf2N/tracks"

request_body = json.dumps({
          "uris" : sad_audio_uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQDBAItJTIw2-Xdn8RZ3ClXWkCAleaI98ZgOZUSsx-g0YvrQJCbGuWPqyKp7lkoAH1esXvIVKYHP5oQFpDLezhq-lLa6KzpadSX9wjNFXJb6lgngRDfc5zcBFScmxoq7en8zBHs5kfqfaAHJKsWG1Dnw710wRRV7uqQsSR1aiv-UQg0AHDLGYSGtBHO2Y2nMpP8319mdj7mE09oFzP5ZHBeMrtQVynk"})

print(response.status_code)
# Out:
# 401

# %%
#happy playlist id (audio) ----- spotify:playlist:5u5KHlhirlVSznJUC0Ta9H

endpoint_url = f"https://api.spotify.com/v1/playlists/5u5KHlhirlVSznJUC0Ta9H/tracks"

request_body = json.dumps({
          "uris" : happy_audio_uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQCEteuS99PUMEzf3-xvoyPcYvezO2X3vRQaTpGqZt-zqsE20JJ8WTcty5ZaPpJ7WxRX3SmOaLTe0WgQQWg9rI01XjiJBatRt338XVbw5n0puM0ntUIv38JQovdPVeGZ21ijUAkJ0Y84RWkySgviG-iwzuV2fzXofZ5A6Of-igxfK8xZWgqCcD8x1utLdD0jGPGdNznkRJf83SQQxrFctSXL9U0fUAE"})

print(response.status_code)
# Out:
# 201

# %%
############################audio features and song lyrics#############################################

# %%
combo_songs = pd.read_csv('Downloads/combo_lyrics_features_predictions.csv')

# %%
#add 'spotify:track:' to spotify ids in df 

for index, row in combo_songs.iterrows():
    songId = str(combo_songs['track_id'][index])
    combo_songs['track_id'][index] = 'spotify:track:' + songId

combo_songs
# Out:
# <ipython-input-21-edd59f324009>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combo_songs['track_id'][index] = 'spotify:track:' + songId
#       Unnamed: 0  Unnamed: 0.1                              track_id  \
# 0              0          8772  spotify:track:3rLZh34oJ1KzLkYwPVYUgP
# 1              1          8821  spotify:track:3ScJy88F8KqGDfWu8XJhHx
# 2              2          1730  spotify:track:0RZXNlGPvfMo54fd6uCvAT
# 3              3          7881  spotify:track:3fCqWsYPCPdLteUpeIOeyQ
# 4              4          7142  spotify:track:31QRCKy7JIwPBaQl9ArGBz
# ...          ...           ...                                   ...
# 5995        5995           144  spotify:track:04g1aQFzaegB7ovWaMMIzz
# 5996        5996          5971  spotify:track:2LBqCSwhJGcFQeTHMVGwy3
# ...

# %%
happy_combo_uris = []
sad_combo_uris = []

for index, row in combo_songs.iterrows():
    if combo_songs['combo_features_preds'][index] == 1:
        happy_combo_uris.append(str(combo_songs['track_id'][index]))
    if combo_songs['combo_features_preds'][index] == 0:
        sad_combo_uris.append(str(combo_songs['track_id'][index]))
        
happy_combo_uris_100 = random.sample(happy_combo_uris, 100)
sad_combo_uris_100 = random.sample(sad_combo_uris, 100)

# %%
#sad playlist id (combo) ----- spotify:playlist:2iTrmmaiJPwUN0VmpmFwT8

endpoint_url = f"https://api.spotify.com/v1/playlists/2iTrmmaiJPwUN0VmpmFwT8/tracks"

request_body = json.dumps({
          "uris" : sad_combo_uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQCAxPFLPGpHoR-CoJ0VrBaGUOYqCq7TjU2Hpa-PmxAn-q1Zyj3No9HujOtI_D0VRZ-Md0ZwLGMcmCCY_U_s7HYxSpD3FmRJiYuCxQSllPgntUpEMikyyjBpdw2RHu6y-9WnCbpWcRFZR58gfi7DLAUq3zSJLAg_Xsu947QzGrXmVPTipMyqiIIQlDHb4CpQFMgwImxSLnRaFjyPjK9-AJbKa99SU04"})

print(response.status_code)
# Out:
# 201

# %%
#happy playlist id (combo) ----- spotify:playlist:2GyBV9ciZXFlSCYfNB0NSP

endpoint_url = f"https://api.spotify.com/v1/playlists/2GyBV9ciZXFlSCYfNB0NSP/tracks"

request_body = json.dumps({
          "uris" : happy_combo_uris_100
        })
response = requests.post(url = endpoint_url, data = request_body, headers={"Content-Type":"application/json", 
                        "Authorization":"Bearer BQDhFnaWWkrkDLvpS9J3SaFBq5bV0Qoq7srilPJyPeMRNdhzxo3VWDUsvrpOB_WkSgcJv_XgujZJ_JWmZRaLA6sgxwElnyH6qi0XFenWxq-EIsRqsQ-5ke3mM7dqdf9NMQbFDqKG7sK-OAjma-2ybj7HVzrkFVfyi3-wSDB_N3mjzCJMtIyrV3l1shg3zE1DO4nuPDMZunvvzLLgIt-sVesd-1ntlXk"})

print(response.status_code)
# Out:
# 201
