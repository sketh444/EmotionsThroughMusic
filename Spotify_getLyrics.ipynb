# %%
conda install -c conda-forge spotipy
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/bellabaidak/opt/anaconda3
#
#   added / updated specs:
#     - spotipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.11.0               |   py38h50d1736_0        16.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        16.9 MB
#
# The following packages will be UPDATED:
#
#   conda                               4.10.3-py38h50d1736_3 --> 4.11.0-py38h50d1736_0
#
#
#
# ...
# conda-4.11.0         | 16.9 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import re
import numpy as np

# %%
#set up connection with spotify api 
cid ='6b389199e4d34beba42d31b47f088560'
secret ='85db5e26a900444296f57878c54d1a63'

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#get df of spotify playlist 
def analyze_playlist(creator, playlist_id):
    
    # Create empty dataframe
    playlist_features_list = ["artist","album","track_name",  "track_id","danceability","energy","key","loudness","mode", "speechiness","instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
    
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    
    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:
        # Create empty dict
        playlist_features = {}
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
#get happy playlists from spotify 
happy1 = analyze_playlist("Spotify", "37i9dQZF1DX9u7XXOp0l5L")
happy2 = analyze_playlist("Spotify", "37i9dQZF1DXdPec7aLTmlC")
happy3 = analyze_playlist("Spotify", "37i9dQZF1DWZKuerrwoAGz")
happy4 = analyze_playlist("Spotify", "37i9dQZF1DX1WSnLRtI26o")
happy5 = analyze_playlist("Spotify", "37i9dQZF1DX1H4LbvY4OJi")
happy6 = analyze_playlist("parislelacheur", "5yI34GDYLxUxfSrpshdNVE")
happy7 = analyze_playlist("Indiemomo", "4AnAUkQNrLKlJCInZGSXRO")
happy8 = analyze_playlist("Ischtar Isik", "3Hs562oYeOsTcNmiUSj0f8")
happy9 = analyze_playlist("Spotify", "37i9dQZF1DXeby79pVadGa")
happy10 = analyze_playlist("Filtr US", "1h90L3LP8kAJ7KGjCV2Xfd")
happy11 = analyze_playlist("Spotify", "37i9dQZF1DWSf2RDTDayIx")
happy12 = analyze_playlist("Amaris Valenca", "0lngUq9w5tBnbeVTiq3ErJ")
happy13 = analyze_playlist("Spotify", "37i9dQZF1DX5YTAi6JhwZm")
happy14 = analyze_playlist("Spotify", "37i9dQZF1DWVOMXLzSabIM")
happy15 = analyze_playlist("Spotify", "37i9dQZF1DX84kJlLdo9vT")
happy16 = analyze_playlist("kaleb.dedrick", "35iJExPpKZr2X1GqWPBO2V")
happy17 = analyze_playlist("Jess Conte", "6M5QoiSaeIq4ZbZYlWJhbF")
happy18 = analyze_playlist("Music life", "6hXwzaSaiiWUazPjpQn0Yl")
happy19 = analyze_playlist("Chrissy Luch", "4MxxPfH8uBt6PG6Z9DfknW")
happy20 = analyze_playlist("Zahori", "3fhqNLBRZYDcuWjyhwvefI")
happy21 = analyze_playlist("skye", "0RH319xCjeU8VyTSqCF6M4")
happy22 = analyze_playlist("Rosaliexcindy", "0dWheZd3cdhezPTHles6Ms")
happy23 = analyze_playlist("e.miller22", "37LibJ2dUWe9FOkgUw98G1")
happy24 = analyze_playlist("Spotify", "37i9dQZF1DX0UrRvztWcAU")
happy25 = analyze_playlist("Vlog No Copyright Music", "6pTTaGg2WTR1fJYpdwHo4K")
happy26 = analyze_playlist("renatoleitewd7", "7a8xfvogHnGzZKQUenPCms")
happy27 = analyze_playlist("j1661", "2OcKutmABxisjbRrSaThVn")
happy28 = analyze_playlist("your own kind of music", "3FqbJH0iGpEo4hZDqsutKT")
happy29 = analyze_playlist("Edward Martin", "7BD7Q1YuR6RPMHZWd5UVcv")
happy30 = analyze_playlist("artistluv101", "78wRZVS9lt5iseEVhS0Ejm")
happy31 = analyze_playlist("ella", "47zZl5XOX2bkbEwJj1dOXi")
happy32 = analyze_playlist("Jaymie Hall", "6pMTZ5uP0s4718eU8bVCkn")
happy33 = analyze_playlist("Spotify", "37i9dQZF1DWVlYsZJXqdym")
happy34 = analyze_playlist("Spotify", "37i9dQZF1DZ06evO3AEHYI")
happy35 = analyze_playlist("terrigkindley", "0gX2QkkchpGMurEvklq7kI")
happy36 = analyze_playlist("Carlos Antonio", "7J4e49SxlE8KhqqXHQIAgK")
happy37 = analyze_playlist("Ashley James", "0IAG5sPikOCo5nvyKJjCYo")
happy38 = analyze_playlist("Chloe Canivel", "2IQ5WPLpRHWiJffXBlrUsj")
happy39 = analyze_playlist("Sophie_maunder", "1tvBTMHfGCD7RLY7tqc75G")
happy40 = analyze_playlist("Spotify", "37i9dQZF1DX4uPi2roRUwU")
happy41 = analyze_playlist("Flopi", "3aIwvgFXmcNVZGPjrki10c")
happy42 = analyze_playlist("lena vu", "0E7XIwYNIcesjeUk4YCZrM")
happy43 = analyze_playlist("steve0418", "4L4Up9lxLqWkJ3EQbaRQHO")
happy44 = analyze_playlist("jennywren", "15gDsBGwq1bPllgI0cFSsc")
happy45 = analyze_playlist("Gareth Doherty", "77m7vYBY8SZW2c1hlIT4S8")
happy46 = analyze_playlist("stay", "4RW2qHVnTcwivFrFuS9tkU")
happy47 = analyze_playlist("Sian Evans", "528SYDVc5gwb5QmGiLeOnb")
happy48 = analyze_playlist("californiagurlz256", "2YUXWB6ahd6SfTifiNyHau")
happy49 = analyze_playlist("Elisabeth Wilson", "6JQePZ4Kg7ed4JN5gRXTKk")
happy50 = analyze_playlist("Asher", "0jgy0bJr7LDIK0XrPhjkng")


#put individual happy playlists together into one df and drop duplicate songs 
happy_songs = pd.concat([happy1, happy2, happy3, happy4, happy5, happy6, happy7, happy8, happy9, happy10, happy11, happy12, happy13, happy14, happy15, happy16, happy17, happy18, happy19, happy20, happy21, happy22, happy23, happy24, happy26, happy27, happy28, happy29, happy30, happy31, happy32, happy33, happy34, happy35, happy36, happy37, happy38, happy39, happy40, happy41, happy42, happy43, happy44, happy45, happy46, happy47, happy48, happy49, happy50], axis=0)
happy_songs = happy_songs.drop_duplicates()

#reseting index
happy_songs = happy_songs.reset_index(drop=True)
happy_songs
# Out:
#                artist                   album              track_name  \
# 0         Thomas Acda      Als Ik Je Weer Zie      Als Ik Je Weer Zie
# 1          Ed Sheeran                 Shivers                 Shivers
# 2         Oleta Adams               Evolution          Window Of Hope
# 3               Ph.D.    I Won't Let You Down    I Won't Let You Down
# 4        Chef'Special                   Amigo                   Amigo
# ...               ...                     ...                     ...
# 3305             Daya  Sit Still, Look Pretty  Sit Still, Look Pretty
# 3306           Avicii  SOS (feat. Aloe Blacc)                     SOS
# 3307           Khalid             Free Spirit                 Hundred
# 3308  Various Artists    Make It Pop, Vol. 16                  Shower
# 3309      I Don't Fly        Really Dont Care        Really Dont Care
#
#                     track_id  danceability  energy key  loudness mode  \
# ...

# %%
#get sad playlists from spotify 
sad1 = analyze_playlist("zoey ng", "4yXfnhz0BReoVfwwYRtPBm")
sad2 = analyze_playlist("Spotify", "37i9dQZF1DWVV27DiNWxkR")
sad3 = analyze_playlist("Spotify", "37i9dQZF1DX6hO1vx5AApi")
sad4 = analyze_playlist("treygammel", "2tN9jIiiCBLCSAVuaVvgHX")
sad5 = analyze_playlist("Spotify", "37i9dQZF1DWW2hj3ZtMbuO")
sad6 = analyze_playlist("Lauren", "38BAFacbwA5kGf7iqcW7Wj")
sad7 = analyze_playlist("Chilled Sad", "70VaOHyjpsWcmA4gxosExZ")
sad8 = analyze_playlist("Lofish Records", "3c0Nv5CY6TIaRszlTZbUFk")
sad9 = analyze_playlist("Spotify", "37i9dQZF1DXaS0Bb5SeHIi")
sad10 = analyze_playlist("JudasVargas", "44tRfteJJzAmUONSiA56bQ")
sad11 = analyze_playlist("Spotify", "37i9dQZF1DWZFicI79sEj9")
sad12 = analyze_playlist("Spotify", "37i9dQZF1DX6xZZEgC9Ubl")
sad13 = analyze_playlist("Rare Candy", "2n5JJJkFQMlmdYOsopsd8n")
sad14 = analyze_playlist("brookeliston", "79TIuxrNXFINvJHF7UoIkc")
sad15 = analyze_playlist("calm beats", "61wCeISpu6SYd6EtLCqPW8")
sad16 = analyze_playlist("Loreen", "3wimKpX6qv4YfsHTdmmqwu")
sad17 = analyze_playlist("Spotify", "37i9dQZF1DXchlyaSeZp0q")
#sad18 = analyze_playlist("emma s", "7MVTg60EjvAGBMi17KD0Nx")
sad18 = analyze_playlist("NateBDawgg", "1Rq0NCl4VVj9zeu025TUMh")
sad19 = analyze_playlist("Chris", "0yCibhQoJwqMq7B3S8Pvb1")
sad20 = analyze_playlist("Spotify", "37i9dQZF1DXa39zZwdBPSN")
sad21 = analyze_playlist("Spotify", "37i9dQZF1DX8Vz2ROLXhTT")
sad22 = analyze_playlist("Spiid3r", "7xySbQAypJdiEBRRlycJIY")
sad23 = analyze_playlist("Filtr US", "3i3r8WqFBreVjamaD5wCeC")
sad24 = analyze_playlist("Spotify", "37i9dQZF1DWSqBruwoIXkA")
sad25 = analyze_playlist("KHart93", "53NEfJTEt86ytgk5SaqMjZ")
sad26 = analyze_playlist("Spotify", "37i9dQZF1DX7qK8ma5wgG1")
sad27 = analyze_playlist("Pernille Bakkehaug", "0v7ALSB6wNw5uLdis40yKs")
sad28 = analyze_playlist("Rosendale", "5FeHyyiioSObGs9mIVqW5b")
sad29 = analyze_playlist("Spotify", "37i9dQZF1DWZUAeYvs88zc")
sad30 = analyze_playlist("Lily Ravel", "16hBhAXKivud4TBL5LpBYM")
sad31 = analyze_playlist("Spaak Records", "6nxPNnmSE0d5WlplUsa5L3")
sad32 = analyze_playlist("Digster Au", "1T3sDN0j3hzg6NE3dbiSmX")
sad33 = analyze_playlist("Promoting Sounds", "4Ao85ZB0F474SYUelDH1Xi")
sad34 = analyze_playlist("Lena McClaugherty", "7kEE6TqULEqEkWETKhXscw")
sad35 = analyze_playlist("discovered", "2V54AkhxCDLeORKeBtDZGr")
sad36 = analyze_playlist("Annik", "54NczufWOFmJ5jUVvRPxaF")
#sad37 = analyze_playlist("slts1994", "J5VOEudOS5iWfq27deI")
sad37 = analyze_playlist("Wovy", "7pKEWS1ddsDJgRrqNRyjMA")
sad38 = analyze_playlist("Spotify", "37i9dQZF1DXe2fHCBYbwN7")
sad39 = analyze_playlist("Spotify", "37i9dQZF1DX2m7zA91yge5")
#sad40 = analyze_playlist("sheila.tyf", "4O77TD3uISefqd9AwW7sOy")
sad40 = analyze_playlist("larissaenkayo", "7ijv3PVaMDMhC9lvTM6QZD")
sad41 = analyze_playlist("Spotify", "37i9dQZF1DX4mWCZw6qYIw")
sad42 = analyze_playlist("Spotify", "37i9dQZF1DWYfVqUciU2jI")
#sad43 = analyze_playlist("Sad Rap", "2LW0SomedVeAi6u5WvJLYr")
sad43 = analyze_playlist("alesha", "5Eh98ARp7dISvHF9hVI3LB")
sad44 = analyze_playlist("Spotify", "37i9dQZF1EId4uQEXLu3QA")
sad45 = analyze_playlist("HAPPY GENIUS", "2HVNytN7Y7gtBor7tL9E0g")
#sad46 = analyze_playlist("Syazwan", "4lpLhbOb74Dd25KTAWkkMw")
sad46 = analyze_playlist("Carla Godsman", "1JgGmeuJgMKVSYw39rG7y6")
sad47 = analyze_playlist("samuel_leadley", "4rFp8l9vekheKOpeJLVkar")
sad48 = analyze_playlist("Iris", "0iG4M6IQturR49BosCjpxm")
sad49 = analyze_playlist("Playlist Pop", "014vY40mh7KcAnCsCwEJVo")
sad50 = analyze_playlist("simonbriesacher", "5jbnb8UVRkjR5Jyb28bMUB")


#put individual happy playlists together into one df and drop duplicate songs 
sad_songs = pd.concat([sad1, sad2, sad3, sad4, sad5, sad6, sad7, sad8, sad9, sad10, sad11, sad12, sad13, sad14, sad15, sad16, sad17, sad18, sad19, sad20, sad21, sad22, sad23, sad24, sad25, sad26, sad27, sad28, sad29, sad30, sad31, sad32, sad33, sad34, sad35, sad36, sad37, sad38, sad39, sad40, sad41, sad42, sad43, sad44, sad45, sad46, sad47, sad48, sad49, sad50], axis=0)
sad_songs = sad_songs.drop_duplicates()

#reseting index
sad_songs = sad_songs.reset_index(drop=True)
sad_songs
# Out:
#                  artist                                              album  \
# 0           Beach House                                  Depression Cherry
# 1         Sarah Cothran                              As the World Caves In
# 2      The Black Skirts                                          TEAM BABY
# 3                  SYML                                               SYML
# 4            Lord Huron                                     Strange Trails
# ...                 ...                                                ...
# 2949     Phosphorescent                                              Pride
# 2950     Sufjan Stevens  Mystery of Love (From the Original Motion Pict...
# 2951  Rex Orange County                                     Loving Is Easy
# 2952       Youth Lagoon                            The Year of Hibernation
# 2953      The Lumineers                                      The Lumineers
#
#                                              track_name  \
# ...

# %%
pip install lyricsgenius
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#setting up connection with genius api 
import lyricsgenius
#genius = lyricsgenius.Genius('-y6AdtZXiphnBu6Ls-n7Kot_j8Si8M0sfA-kd_ZH3gUVURe8d_o98H3oFPrnKoeN')
genius = lyricsgenius.Genius('9VWEx6O3RCG11F-1o-1RlT_dln64zJLMsgr_6VXpFabhOoCOhrGCqY5f0da8p1Vv',  timeout=15, retries=3)

# %%
# def get_lyrics(df):
#     df['lyrics'] = df.apply(lambda row: genius.search_song(str(row['track_name']), str(row['artist'])).lyrics if genius.search_song(str(row['track_name']), str(row['artist'])) != None else 'none', axis=1)

#get_lyrics(sad_songs)

# %%
# def remove_none(df): 
#     for index, row in df.iterrows():
#         if df['lyrics'][index] == 'none':
#                df = df.drop([index]) 

# remove_none(sad_songs)

# sad_songs

# %%
genius.remove_section_headers = True # Remove section headers (e.g. [Chorus]) from lyrics when searching
genius.skip_non_songs = True

#get song lyrics from genius 
def get_lyrics(song, artist): 
        song = genius.search_song(song, artist)
        if song == None: 
            return 'none'
        else: 
           return song.lyrics


happy_songs_split = np.array_split(happy_songs, 5)

# %%
#happy songs
lyrics = []
for index, row in happy_songs_split[0].iterrows():
    song = get_lyrics(str(happy_songs_split[0]['track_name'][index]), str(happy_songs_split[0]['artist'][index]))
    lyrics.append(song)
    
happy_songs_split[0]['lyrics'] = lyrics

happy_songs_split[0]
# Out:
# Searching for "Als Ik Je Weer Zie" by Thomas Acda...
# Done.
# Searching for "Shivers" by Ed Sheeran...
# Done.
# Searching for "Window Of Hope" by Oleta Adams...
# Done.
# Searching for "I Won't Let You Down" by Ph.D....
# Done.
# Searching for "Amigo" by Chef'Special...
# Done.
# Searching for "Blijven Slapen" by Snelle...
# Done.
# Searching for "A Brand New Day" by Various Artists...
# Done.
# Searching for "Bad Habits" by Ed Sheeran...
# Done.
# Searching for "So Incredible" by Ilse DeLange...
# Done.
# Searching for "Girl" by Anouk...
# Done.
# Searching for "Valerie (feat. Amy Winehouse) - Version Revisited" by Mark Ronson...
# Done.
# Searching for "Hoe Het Danst" by Marco Borsato...
# Done.
# Searching for "Zoutelande" by BLØF...
# Done.
# Searching for "Happy Ending" by Joe Jackson...
# Done.
# Searching for "In Your Arms" by Chef'Special...
# Done.
# Searching for "Streets" by Kensington...
# Done.
# Searching for "You And Me" by Spargo...
# Done.
# ...

# %%
lyrics = []
for index, row in happy_songs_split[1].iterrows():
    song = get_lyrics(str(happy_songs_split[1]['track_name'][index]), str(happy_songs_split[1]['artist'][index]))
    lyrics.append(song)
    
    
happy_songs_split[1]['lyrics'] = lyrics

happy_songs_split[1]
# Out:
# Searching for "I Knew You Were Waiting (For Me)" by George Michael...
# Done.
# Searching for "Don't Be so Hard on Yourself" by Jess Glynne...
# Done.
# Searching for "Walking on Broken Glass" by Annie Lennox...
# Done.
# Searching for "I'm So Excited" by The Pointer Sisters...
# Done.
# Searching for "Relight My Fire (feat. Lulu) - UK Radio Edit" by Take That...
# No results found for: 'Relight My Fire (feat. Lulu) - UK Radio Edit Take That'
# Searching for "I Say a Little Prayer" by Aretha Franklin...
# Done.
# Searching for "High" by Lighthouse Family...
# Done.
# Searching for "Coming Around Again" by Simon Webbe...
# Done.
# Searching for "Faith (with Dolly Parton) [feat. Mr. Probz]" by Galantis...
# Done.
# Searching for "September" by Earth, Wind & Fire...
# Done.
# Searching for "World of Our Own" by Westlife...
# Done.
# Searching for "Move" by The Mamas...
# Done.
# Searching for "No Judgement" by Niall Horan...
# Done.
# Searching for "I'm Coming Out" by Diana Ross...
# ...

# %%
lyrics = []
for index, row in happy_songs_split[2].iterrows():
    song = get_lyrics(str(happy_songs_split[2]['track_name'][index]), str(happy_songs_split[2]['artist'][index]))
    lyrics.append(song)
    
    
happy_songs_split[2]['lyrics'] = lyrics

happy_songs_split[2]
# Out:
# Searching for "Haven't Met You Yet" by Michael Bublé...
# Done.
# Searching for "Waiting On the World to Change" by John Mayer...
# Done.
# Searching for "Fallin' For You" by Colbie Caillat...
# Done.
# Searching for "I Won't Give Up" by Jason Mraz...
# Done.
# Searching for "1, 2, 3, 4" by Plain White T's...
# Done.
# Searching for "I Got You" by Jack Johnson...
# Done.
# Searching for "Smile" by Uncle Kracker...
# Done.
# Searching for "You Are the Best Thing" by Ray LaMontagne...
# Done.
# Searching for "Bright" by Echosmith...
# Done.
# Searching for "Sunrise" by Norah Jones...
# Done.
# Searching for "Rhythm Of Love" by Plain White T's...
# Done.
# Searching for "First Day Of My Life" by Bright Eyes...
# Done.
# Searching for "I'm Yours" by Jason Mraz...
# Done.
# Searching for "Have It All" by Jason Mraz...
# Done.
# Searching for "Riptide" by Vance Joy...
# Done.
# Searching for "Over the Rainbow" by Israel Kamakawiwo'ole...
# Done.
# ...

# %%
lyrics = []
for index, row in happy_songs_split[4].iterrows():
    song = get_lyrics(str(happy_songs_split[4]['track_name'][index]), str(happy_songs_split[4]['artist'][index]))
    lyrics.append(song)
    
    
happy_songs_split[4]['lyrics'] = lyrics

happy_songs_split[4]
# Out:
# Searching for "Josslyn" by Olivia O'Brien...
# Done.
# Searching for "I'm Still Standing" by Various Artists...
# Done.
# Searching for "Somebody To Love - Remastered 2011" by Queen...
# Done.
# Searching for "Killer Queen - Remastered 2011" by Queen...
# Done.
# Searching for "Fat Bottomed Girls - 2011 Remaster" by Queen...
# Done.
# Searching for "Good Old-Fashioned Lover Boy - Remastered 2011" by Queen...
# No results found for: 'Good Old-Fashioned Lover Boy - Remastered 2011 Queen'
# Searching for "Fabulous" by Various Artists...
# Done.
# Searching for "Whatcha Say" by Jason Derulo...
# Done.
# Searching for "Like A G6" by Far East Movement...
# Done.
# Searching for "I Gotta Feeling" by Black Eyed Peas...
# Done.
# Searching for "Starships" by Nicki Minaj...
# Done.
# Searching for "Fuck You" by CeeLo Green...
# Done.
# Searching for "Airplanes (feat. Hayley Williams of Paramore)" by B.o.B...
# Done.
# Searching for "Life Of The Party" by Shawn Mendes...
# Done.
# ...

# %%
lyrics = []
for index, row in happy_songs_split[3].iterrows():
    song = get_lyrics(str(happy_songs_split[3]['track_name'][index]), str(happy_songs_split[3]['artist'][index]))
    lyrics.append(song)
    
    
happy_songs_split[3]['lyrics'] = lyrics

happy_songs_split[3]
# Out:
# Searching for "Somebody To You" by The Vamps...
# Done.
# Searching for "The Sound Of Sunshine" by Michael Franti & Spearhead...
# Done.
# Searching for "You've Got a Friend in Me - From "Toy Story"/Soundtrack Version" by Randy Newman...
# Done.
# Searching for "Try Everything - From "Zootropolis"" by Shakira...
# No results found for: 'Try Everything - From "Zootropolis" Shakira'
# Searching for "22" by Taylor Swift...
# Done.
# Searching for "Gone, Gone, Gone" by Phillip Phillips...
# Done.
# Searching for "Just a Friend" by Biz Markie...
# Done.
# Searching for "Mine" by Bazzi...
# Done.
# Searching for "Castle on the Hill" by Ed Sheeran...
# Done.
# Searching for "Fight Song" by Rachel Platten...
# Done.
# Searching for "Can't Blame a Girl for Trying" by Sabrina Carpenter...
# Done.
# Searching for "The Middle of Starting Over" by Sabrina Carpenter...
# Done.
# Searching for "Had Me @ Hello" by Various Artists...
# Done.
# Searching for "Eyes Wide Open" by Sabrina Carpenter...
# ...

# %%
happy_songs = pd.concat([happy_songs_split[0], happy_songs_split[1], happy_songs_split[2], happy_songs_split[3], happy_songs_split[4]], axis=0)
happy_songs
# Out:
#                artist                   album              track_name  \
# 0         Thomas Acda      Als Ik Je Weer Zie      Als Ik Je Weer Zie
# 1          Ed Sheeran                 Shivers                 Shivers
# 2         Oleta Adams               Evolution          Window Of Hope
# 3               Ph.D.    I Won't Let You Down    I Won't Let You Down
# 4        Chef'Special                   Amigo                   Amigo
# ...               ...                     ...                     ...
# 3305             Daya  Sit Still, Look Pretty  Sit Still, Look Pretty
# 3306           Avicii  SOS (feat. Aloe Blacc)                     SOS
# 3307           Khalid             Free Spirit                 Hundred
# 3308  Various Artists    Make It Pop, Vol. 16                  Shower
# 3309      I Don't Fly        Really Dont Care        Really Dont Care
#
#                     track_id  danceability  energy key  loudness mode  \
# ...

# %%
genius.remove_section_headers = True # Remove section headers (e.g. [Chorus]) from lyrics when searching
genius.skip_non_songs = True

#sad songs
lyrics = []
for index, row in sad_songs.iterrows():
    song = get_lyrics(str(sad_songs['track_name'][index]), str(sad_songs['artist'][index]))
    lyrics.append(song)
    
sad_songs['lyrics'] = lyrics

sad_songs
# Out:
# Searching for "Space Song" by Beach House...
# Done.
# Searching for "As the World Caves In" by Sarah Cothran...
# Done.
# Searching for "EVERYTHING" by The Black Skirts...
# Done.
# Searching for "Where's My Love" by SYML...
# Done.
# Searching for "The Night We Met" by Lord Huron...
# Done.
# Searching for "IDK You Yet" by Alexander 23...
# Done.
# Searching for "traitor" by Olivia Rodrigo...
# Done.
# Searching for "Vas" by jagger finn...
# Done.
# Searching for "happier" by Olivia Rodrigo...
# Done.
# Searching for "Daddy Issues (Slowed Remix)" by zukrai...
# No results found for: 'Daddy Issues (Slowed Remix) zukrai'
# Searching for "Je te laisserai des mots" by Patrick Watson...
# Done.
# Searching for "Home" by Edith Whiskers...
# Done.
# Searching for "Stan" by Eminem...
# Done.
# Searching for "You're Somebody Else" by flora cash...
# Done.
# Searching for "It Will Rain" by Bruno Mars...
# Done.
# Searching for "Black Out Days - Future Islands Remix" by Phantogram...
# Done.
# ...

# %%
#drop nones from df 

def remove_none(df): 
    for index, row in df.iterrows():
        if df['lyrics'][index] == 'none':
            df = df.drop([index])
        return df

remove_none(sad_songs)
remove_none(happy_songs)


# for index, row in happy_songs.iterrows():
#     if happy_songs['lyrics'][index] == 'none':
#            happy_songs = happy_songs.drop([index])


#add 1 for isHappy 
happy_songs['isHappy'] = 1
#happy_songs

#add 0 for isHappy 
sad_songs['isHappy'] = 0
#sad_songs

all_songs = pd.concat([happy_songs, sad_songs], axis=0)
all_songs = all_songs.drop_duplicates()
all_songs = all_songs.reset_index(drop=True)


remove_none(all_songs)

#all_songs
# Out:
#                  artist                                              album  \
# 0           Thomas Acda                                 Als Ik Je Weer Zie
# 1            Ed Sheeran                                            Shivers
# 2           Oleta Adams                                          Evolution
# 3                 Ph.D.                               I Won't Let You Down
# 4          Chef'Special                                              Amigo
# ...                 ...                                                ...
# 6259     Phosphorescent                                              Pride
# 6260     Sufjan Stevens  Mystery of Love (From the Original Motion Pict...
# 6261  Rex Orange County                                     Loving Is Easy
# 6262       Youth Lagoon                            The Year of Hibernation
# 6263      The Lumineers                                      The Lumineers
#
#                                              track_name  \
# ...

# %%
happy_songs.to_csv('happy_songs_1125.csv')

# %%
sad_songs.to_csv('sad_songs_1125.csv')

# %%
all_songs.to_csv('all_songs_1125.csv')

# %%
for index, row in all_songs.iterrows():
    if all_songs['lyrics'][index] == 'none':
            all_songs = all_songs.drop([index])


all_songs = all_songs.reset_index(drop=True)
all_songs
# Out:
#                  artist                    album            track_name  \
# 0           Thomas Acda       Als Ik Je Weer Zie    Als Ik Je Weer Zie
# 1            Ed Sheeran                  Shivers               Shivers
# 2           Oleta Adams                Evolution        Window Of Hope
# 3                 Ph.D.     I Won't Let You Down  I Won't Let You Down
# 4          Chef'Special                    Amigo                 Amigo
# ...                 ...                      ...                   ...
# 5765            Alvvays           Antisocialites         Dreams Tonite
# 5766     Phosphorescent                    Pride                Wolves
# 5767  Rex Orange County           Loving Is Easy        Loving Is Easy
# 5768       Youth Lagoon  The Year of Hibernation                    17
# 5769      The Lumineers            The Lumineers              Dead Sea
#
#                     track_id  danceability  energy key  loudness mode  \
# ...

# %%
all_songs.to_csv('all_songs_1126_noNONE.csv')

# %%
#remove various artist songs from dataset

for index, row in all_songs.iterrows():
    if all_songs['artist'][index] == 'Various Artists':
            all_songs = all_songs.drop([index])


#reseting index
all_songs = all_songs.reset_index(drop=True)
all_songs
# Out:
#                  artist                    album            track_name  \
# 0           Thomas Acda       Als Ik Je Weer Zie    Als Ik Je Weer Zie
# 1            Ed Sheeran                  Shivers               Shivers
# 2           Oleta Adams                Evolution        Window Of Hope
# 3                 Ph.D.     I Won't Let You Down  I Won't Let You Down
# 4          Chef'Special                    Amigo                 Amigo
# ...                 ...                      ...                   ...
# 5765            Alvvays           Antisocialites         Dreams Tonite
# 5766     Phosphorescent                    Pride                Wolves
# 5767  Rex Orange County           Loving Is Easy        Loving Is Easy
# 5768       Youth Lagoon  The Year of Hibernation                    17
# 5769      The Lumineers            The Lumineers              Dead Sea
#
#                     track_id  danceability  energy key  loudness mode  \
# ...

# %%
 pip install langdetect
# Out:
# ...
#      |████████████████████████████████| 981 kB 5.3 MB/s eta 0:00:01
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=81fc0bf0573e76a2b35051c54724f992328acbe291ee640823f2fd4a3a4a9a39
#   Stored in directory: /Users/bellabaidak/Library/Caches/pip/wheels/13/c7/b0/79f66658626032e78fc1a83103690ef6797d551cb22e56e734
# Successfully built langdetect
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langdetect import detect
detect(all_songs['lyrics'][0])
# Out:
# 'nl'

# %%
#removing non english lyrics 
for index, row in all_songs.iterrows():
    if detect(all_songs['lyrics'][index]) != 'en':
           all_songs = all_songs.drop([index])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-172-7afa50dd333b> in <module>
#       1 #removing non english lyrics
#       2 for index, row in all_songs.iterrows():
# ----> 3     if detect(all_songs['lyrics'][index]) != 'en':
#       4            all_songs = all_songs.drop([index])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/langdetect/detector_factory.py in detect(text)
#     128     detector = _factory.create()
#     129     detector.append(text)
# --> 130     return detector.detect()
#     131
#     132
#
# ~/opt/anaconda3/lib/python3.8/site-packages/langdetect/detector.py in detect(self)
#     134         which has the highest probability.
#     135         '''
# --> 136         probabilities = self.get_probabilities()
#     137         if probabilities:
#     138             return probabilities[0].lang
#
# ...

# %%
#reseting index
all_songs = all_songs.reset_index(drop=True)
all_songs
# Out:
#                  artist                    album            track_name  \
# 0            Ed Sheeran                  Shivers               Shivers
# 1           Oleta Adams                Evolution        Window Of Hope
# 2                 Ph.D.     I Won't Let You Down  I Won't Let You Down
# 3          Chef'Special                    Amigo                 Amigo
# 4            Ed Sheeran               Bad Habits            Bad Habits
# ...                 ...                      ...                   ...
# 5685            Alvvays           Antisocialites         Dreams Tonite
# 5686     Phosphorescent                    Pride                Wolves
# 5687  Rex Orange County           Loving Is Easy        Loving Is Easy
# 5688       Youth Lagoon  The Year of Hibernation                    17
# 5689      The Lumineers            The Lumineers              Dead Sea
#
#                     track_id  danceability  energy key  loudness mode  \
# ...

# %%
count = 0 
for index, row in all_songs.iterrows():
    if all_songs['isHappy'][index] == 1:
        count +=1
print(count)

# %%
all_songs.to_csv('all_songs_1126_noNONE_allEN.csv')
